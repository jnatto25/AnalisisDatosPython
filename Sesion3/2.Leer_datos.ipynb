# %%
pip install "pymongo[srv]"
# Out:
# ...
# WARNING: pymongo 4.10.1 does not provide the extra 'srv'
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 22.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sqlalchemy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 25.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.1/613.1 kB 5.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysqlclient
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mysqlclient: filename=mysqlclient-2.2.7-cp312-cp312-linux_x86_64.whl size=136738 sha256=7982cffeab1bec07bf8a826c0591f8e2d4ead1379276626c59d451f1f04cd046
#   Stored in directory: /home/codespace/.cache/pip/wheels/27/95/18/7f176fffd46629e710c04c810b9c4d7d4358fe7c96a7d2306d
# Successfully built mysqlclient
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy as db
from sqlalchemy import text
import pandas as pd

# %%
engine = db.create_engine("mysql://root:root@127.0.0.1:3310/retail_db")
conn = engine.connect()

# %%
customers_df = pd.read_sql_query("select * from customers", con=conn)
customers_df
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 0                1        Richard      Hernandez      XXXXXXXXX
# 1                2           Mary        Barrett      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# 3                4           Mary          Jones      XXXXXXXXX
# 4                5         Robert         Hudson      XXXXXXXXX
# ...            ...            ...            ...            ...
# 12430        12431           Mary           Rios      XXXXXXXXX
# 12431        12432         Angela          Smith      XXXXXXXXX
# 12432        12433       Benjamin         Garcia      XXXXXXXXX
# 12433        12434           Mary          Mills      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password             customer_street customer_city  \
# 0             XXXXXXXXX          6303 Heather Plaza   Brownsville
# ...

# %%
customers_df_2 = pd.read_sql_table('categories', engine)
customers_df_2
# Out:
#     category_id  category_department_id         category_name
# 0             1                       2              Football
# 1             2                       2                Soccer
# 2             3                       2   Baseball & Softball
# 3             4                       2            Basketball
# 4             5                       2              Lacrosse
# 5             6                       2      Tennis & Racquet
# 6             7                       2                Hockey
# 7             8                       2           More Sports
# 8             9                       3      Cardio Equipment
# 9            10                       3     Strength Training
# 10           11                       3   Fitness Accessories
# 11           12                       3          Boxing & MMA
# 12           13                       3           Electronics
# 13           14                       3        Yoga & Pilates
# ...

# %%
from pymongo import MongoClient

conn_string = "mongodb+srv://jrenatto25:ArvmCwUEGtpoUkwY@cluster0.9axum.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client = MongoClient(conn_string)

client['bd_test']
# Out:
# Database(MongoClient(host=['cluster0-shard-00-01.9axum.mongodb.net:27017', 'cluster0-shard-00-00.9axum.mongodb.net:27017', 'cluster0-shard-00-02.9axum.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-n283ph-shard-0', tls=True), 'bd_test')

# %%
coleccion = client['sample_mflix']['comments']
cursor_mogo = coleccion.find({})

df = pd.DataFrame(cursor_mogo)
df
# Out:
#                             _id            name  \
# 0      5a9427648b0beebeb69579e7  Mercedes Tyler
# 1      5a9427648b0beebeb69579f5     John Bishop
# 2      5a9427648b0beebeb6957a21    Jaqen H'ghar
# 3      5a9427648b0beebeb6957a22    Taylor Scott
# 4      5a9427648b0beebeb6957a38    Yara Greyjoy
# ...                         ...             ...
# 41074  5a9427658b0beebeb697c337    Roose Bolton
# 41075  5a9427658b0beebeb697c339           Gilly
# 41076  5a9427658b0beebeb697c36e   Thoros of Myr
# 41077  5a9427658b0beebeb697c37a   Teresa Thomas
# 41078  5a9427658b0beebeb697c39c   Melissa Jones
#
#                                    email                  movie_id  \
# 0           mercedes_tyler@fakegmail.com  573a1390f29313caabcd4323
# 1              john_bishop@fakegmail.com  573a1390f29313caabcd446f
# 2           tom_wlaschiha@gameofthron.es  573a1390f29313caabcd516c
# 3             taylor_scott@fakegmail.com  573a1390f29313caabcd4eaf
# ...

# %%
departmets_df = pd.read_sql_query("select * from departments", con=conn)
departmets_df
# Out:
#    department_id department_name
# 0              2         Fitness
# 1              3        Footwear
# 2              4         Apparel
# 3              5            Golf
# 4              6        Outdoors
# 5              7        Fan Shop

# %%
dbname = client['retail_db']
coleccion = dbname['departmets']

df_to_dict = departmets_df.to_dict("records")

coleccion.insert_many(df_to_dict)
# Out:
# InsertManyResult([ObjectId('67905f14698b23e093c4b6f5'), ObjectId('67905f14698b23e093c4b6f6'), ObjectId('67905f14698b23e093c4b6f7'), ObjectId('67905f14698b23e093c4b6f8'), ObjectId('67905f14698b23e093c4b6f9'), ObjectId('67905f14698b23e093c4b6fa')], acknowledged=True)

# %%
df_to_dict
# Out:
# [{'department_id': 2, 'department_name': 'Fitness'},
#  {'department_id': 3, 'department_name': 'Footwear'},
#  {'department_id': 4, 'department_name': 'Apparel'},
#  {'department_id': 5, 'department_name': 'Golf'},
#  {'department_id': 6, 'department_name': 'Outdoors'},
#  {'department_id': 7, 'department_name': 'Fan Shop'}]
